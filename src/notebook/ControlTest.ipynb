# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import control as cs
import control.pzmap as pz
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed

# %% [markdown]
# # P1 Element

# %% [markdown]
# Erstellung des P1 Elements mit variablen K und T.

# %%
K = 1.0
T = 1.0

P1 = cs.tf([K],[T,1])

# %% [markdown]
# Übertragungsfunktion im s-Space

# %%
print(P1)
# Out:
#   1
# -----
# s + 1

# %% [markdown]
# Ausgabe der Sprungantwort vom P1 Element.

# %%
y,t = cs.step(P1)
plt.plot(t,y)
plt.xlim(0,3)
plt.xlabel("Zeit in s")

# %% [markdown]
# Analyse der Pol- Nullstellen.

# %%
pole, zero = pz.pzmap(P1)

# %% [markdown]
# Bodediagram vom P1 Element.

# %%
mag, phase, omega = cs.bode(P1,dB=True,Hz=True)

# %% [markdown]
# Nyquistdiagram vom P1 Element.

# %%
real, imag, fraq = cs.nyquist(P1)

# %% [markdown]
# # Test für Interaktive Eingaben

# %%
@interact
def interactTest(K=widgets.FloatSlider(min=0.1,max=20,step=0.1,value=1.0), 
                 T=widgets.FloatSlider(min=1,max=20,step=0.1,value=0.0) ):
    P2 = cs.tf([K],[T,1.0])
    print(P2)
    y,t = cs.step(P2)
    plt.plot(t,y)
    plt.xlim(0,3)
    plt.xlabel("Zeit in s")
# Out:
#   1
# -----
# s + 1
